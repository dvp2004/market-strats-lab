# %% [markdown]
# # Regime-Informed Results Dashboard
#
# NO LIVE TRADING
#
# NO REAL MONEY
#
# NO BROKER/API
#
# NO STRATEGY PROMOTION
#
# This notebook reads local CSV reports only and summarizes the current manual paper workflow.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..').resolve()
DATA = {
    'candidate_summary': ROOT / 'reports/strategy_factory/regime_stress/phase21a_candidate_regime_summary.csv',
    'robustness_scores': ROOT / 'reports/strategy_factory/regime_stress/phase21a_regime_robustness_scores.csv',
    'score_components': ROOT / 'reports/strategy_factory/regime_stress/phase21a_regime_robustness_score_components.csv',
    'regime_metrics': ROOT / 'reports/strategy_factory/regime_stress/phase21a_regime_metrics.csv',
    'shortlist': ROOT / 'reports/strategy_factory/regime_reconciliation/phase21b_paper_shortlist_recommendation.csv',
    'targets': ROOT / 'reports/paper_trading/regime_informed_tracking/regime_informed_paper_targets.csv',
    'tear_sheet': ROOT / 'reports/paper_trading/regime_informed_tracking/regime_informed_daily_tracking_tear_sheet.csv',
    'discipline': ROOT / 'reports/paper_trading/regime_informed_tracking/regime_informed_session_discipline_summary.csv',
    'ledger': ROOT / 'reports/paper_trading/regime_informed_tracking/regime_informed_manual_session_ledger.csv',
    'session_ingestion_status': ROOT / 'reports/paper_trading/dashboard/regime_informed_session_ingestion_status.csv',
    'daily_runtime': ROOT / 'reports/paper_trading/dashboard/daily_paper_runtime_status.csv',
}

def read_csv(path):
    if not path.exists():
        return pd.DataFrame({'missing_file': [str(path)]})
    return pd.read_csv(path)

frames = {name: read_csv(path) for name, path in DATA.items()}
pd.DataFrame({'source': list(DATA), 'path': [str(path) for path in DATA.values()], 'exists': [path.exists() for path in DATA.values()]})
# Out:
#                       source  \
# 0          candidate_summary
# 1          robustness_scores
# 2           score_components
# 3             regime_metrics
# 4                  shortlist
# 5                    targets
# 6                 tear_sheet
# 7                 discipline
# 8                     ledger
# 9   session_ingestion_status
# 10             daily_runtime
#
#                                                  path  exists
# 0   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 1   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 2   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 3   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 4   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 5   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 6   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 7   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 8   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 9   C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True
# 10  C:\Users\Devesh Pansare\Desktop\Personal_Proje...    True

# %% [markdown]
# ## 1. Project Status

# %%
frames['daily_runtime'].head() if not frames['daily_runtime'].empty else 'Daily runtime status missing'
# Out:
#      run_date selected_signal_date  daily_paper_only  \
# 0  2026-06-11           2026-06-08              True
#
#                                          modules_run  \
# 0  phase15q;phase15r;phase15o;phase15p;phase15m;p...
#
#                                      modules_skipped  runtime_seconds  \
# 0  phase17_strategy_factory;phase17b_robustness;p...            0.618
#
#    fresh_signal_available  regime_informed_targets_written  \
# 0                    True                             True
#
#                                      adoption_status  \
# 0  regime_informed_shortlist_adopted_manual_paper...
#
#      session_ingestion_status  ledger_row_count  warnings_present  \
# 0  valid_manual_paper_session                11              True
#
#   blocking_symbols  promotion_allowed  live_trading_allowed  \
# 0             none              False                 False
#
#    real_money_allowed  broker_api_integration_allowed  \
# 0               False                           False
#
#                                  daily_paper_status  \
# 0  daily_paper_workflow_completed_manual_paper_only
#
#                                               notes
# 0  daily_paper_workflow_completed_manual_paper_only

# %% [markdown]
# ## 2. Current Regime-Informed Shortlist

# %%
frames['shortlist'].head(10) if not frames['shortlist'].empty else 'Shortlist report missing'
# Out:
#                              canonical_candidate_id  \
# 0  phase6b_loose_relief_execution_realistic_overlay
# 1             canonical_spy_qqq_gld_tlt_50_30_10_10
# 2         canonical_inverse_vol_63d_btc_usd_qqq_spy
# 3                           canonical_spy_qqq_60_40
#
#                      recommended_role  \
# 0          provisional_core_candidate
# 1  provisional_core_inception_limited
# 2   provisional_high_caveat_candidate
# 3                      reference_only
#
#                              phase21a_classification  \
# 0    provisional_core_candidate_for_further_research
# 1  provisional_core_inception_limited_for_further...
# 2  provisional_high_caveat_candidate_for_further_...
# 3                            rejected_regime_fragile
#
#    phase21a_regime_robustness_score  phase21a_worst_drawdown_pct  \
# 0                             61.48                       -24.12
# 1                             56.32                       -42.73
# 2                             51.82                       -28.02
# 3                             13.39                       -65.22
#
#                            phase21a_blocking_reasons  \
# 0                                                NaN
# 1             asset_inception_limited_regime_history
# 2      btc_inception_limited_pre_2014_regime_history
# 3  severe_drawdown_worse_than_minus_50pct;crash_d...
#
#                                recommendation_reason  \
# 0  best drawdown-control baseline and original de...
# 1  multi-asset regime survivability candidate aft...
# 2  current high-caveat BTC paper candidate remain...
# 3  return-strong growth benchmark useful as refer...
#
#                           recommendation_limitations  currently_paper_tracked  \
# 0  provisional research candidate only; not promoted                    False
# 1  asset inception limited and still requires man...                    False
# 2  BTC inception, weekend/gap, and paper-only cav...                     True
# 3  rejected by regime hard gates due severe drawd...                     True
#
#    promotion_allowed  paper_only  live_trading_allowed  real_money_allowed  \
# 0              False        True                 False               False
# 1              False        True                 False               False
# 2              False        True                 False               False
# 3              False        True                 False               False
#
#    broker_api_integration_allowed
# 0                           False
# 1                           False
# 2                           False
# 3                           False

# %% [markdown]
# ## 3. Why SPY/QQQ 60/40 Was Downgraded

# %%
summary = frames['candidate_summary']
summary[summary.get('canonical_candidate_id', pd.Series(dtype=str)).astype(str).eq('canonical_spy_qqq_60_40')] if not summary.empty else 'Candidate summary missing'
# Out:
#     canonical_candidate_id          candidate_role asset_roster  uses_btc  \
# 2  canonical_spy_qqq_60_40  clean_growth_reference      SPY,QQQ     False
#
#                           equity_curve_source  equity_curve_daily_verified  \
# 2  strategy_factory_reconstructed_daily_curve                         True
#
#    equity_curve_missing_reason  uses_aggregate_metrics_only  \
# 2                          NaN                        False
#
#    regimes_available  regimes_unavailable  positive_return_regimes  \
# 2                  9                    0                        5
#
#    beat_spy_regimes  worst_max_drawdown_pct  mean_total_return_pct  \
# 2                 7                  -65.22                 205.41
#
#    mean_calmar  mean_excess_total_return_vs_spy_pct regime_metric_status
# 2        0.318                                56.32             computed

# %% [markdown]
# ## 4. Phase6 vs Multi-Asset vs BTC Candidates

# %%
targets = frames['targets']
targets[['canonical_candidate_id','candidate_role','asset','target_weight','candidate_caveats']].head(40) if {'canonical_candidate_id','candidate_role','asset','target_weight','candidate_caveats'}.issubset(targets.columns) else targets.head()
# Out:
#                               canonical_candidate_id  \
# 0   phase6b_loose_relief_execution_realistic_overlay
# 1   phase6b_loose_relief_execution_realistic_overlay
# 2              canonical_spy_qqq_gld_tlt_50_30_10_10
# 3              canonical_spy_qqq_gld_tlt_50_30_10_10
# 4              canonical_spy_qqq_gld_tlt_50_30_10_10
# 5              canonical_spy_qqq_gld_tlt_50_30_10_10
# 6          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 7          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 8          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 9                            canonical_spy_qqq_60_40
# 10                           canonical_spy_qqq_60_40
#
#                         candidate_role    asset  target_weight  \
# 0           provisional_core_candidate      SPY           1.00
# 1           provisional_core_candidate     CASH           0.00
# 2   provisional_core_inception_limited      SPY           0.50
# 3   provisional_core_inception_limited      QQQ           0.30
# 4   provisional_core_inception_limited      GLD           0.10
# 5   provisional_core_inception_limited      TLT           0.10
# 6    provisional_high_caveat_candidate      SPY           0.50
# 7    provisional_high_caveat_candidate      QQQ           0.45
# 8    provisional_high_caveat_candidate  BTC-USD           0.05
# 9                       reference_only      SPY           0.60
# 10                      reference_only      QQQ           0.40
#
#                                     candidate_caveats
# 0   original defensive overlay baseline; lower dra...
# 1   original defensive overlay baseline; lower dra...
# 2   multi-asset regime survivability candidate; as...
# 3   multi-asset regime survivability candidate; as...
# 4   multi-asset regime survivability candidate; as...
# 5   multi-asset regime survivability candidate; as...
# 6   BTC high-caveat; inception-limited; weekend/ga...
# 7   BTC high-caveat; inception-limited; weekend/ga...
# 8   BTC high-caveat; inception-limited; weekend/ga...
# 9   reference-only growth benchmark; rejected by r...
# 10  reference-only growth benchmark; rejected by r...

# %% [markdown]
# ## 5. Regime Robustness Scores
#
# ![robustness_scores](reports/paper_trading/regime_informed_tracking/visuals/robustness_scores.png)

# %% [markdown]
# ## 6. Worst Drawdown Comparison
#
# ![worst_drawdowns](reports/paper_trading/regime_informed_tracking/visuals/worst_drawdowns.png)
#
# ![return_vs_drawdown](reports/paper_trading/regime_informed_tracking/visuals/return_vs_drawdown.png)

# %% [markdown]
# ## 7. Regime Return Heatmap
#
# ![regime_return_heatmap](reports/paper_trading/regime_informed_tracking/visuals/regime_return_heatmap.png)

# %% [markdown]
# ## 8. Regime Drawdown Heatmap
#
# ![regime_drawdown_heatmap](reports/paper_trading/regime_informed_tracking/visuals/regime_drawdown_heatmap.png)

# %% [markdown]
# ## 9. Current Target Allocations
#
# ![current_allocations](reports/paper_trading/regime_informed_tracking/visuals/current_allocations.png)

# %% [markdown]
# ## 10. Paper Discipline / Ledger Status

# %%
ledger = frames['ledger']
ledger.tail(20) if not ledger.empty else 'Manual session ledger missing or empty'
# Out:
#    session_date selected_signal_date  \
# 0    2026-06-11           2026-06-08
# 1    2026-06-11           2026-06-08
# 2    2026-06-11           2026-06-08
# 3    2026-06-11           2026-06-08
# 4    2026-06-11           2026-06-08
# 5    2026-06-11           2026-06-08
# 6    2026-06-11           2026-06-08
# 7    2026-06-11           2026-06-08
# 8    2026-06-11           2026-06-08
# 9    2026-06-11           2026-06-08
# 10   2026-06-11           2026-06-08
#
#                               canonical_candidate_id  \
# 0   phase6b_loose_relief_execution_realistic_overlay
# 1   phase6b_loose_relief_execution_realistic_overlay
# 2              canonical_spy_qqq_gld_tlt_50_30_10_10
# 3              canonical_spy_qqq_gld_tlt_50_30_10_10
# 4              canonical_spy_qqq_gld_tlt_50_30_10_10
# 5              canonical_spy_qqq_gld_tlt_50_30_10_10
# 6          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 7          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 8          canonical_inverse_vol_63d_btc_usd_qqq_spy
# 9                            canonical_spy_qqq_60_40
# 10                           canonical_spy_qqq_60_40
#
#                         candidate_role    asset  target_weight  \
# 0           provisional_core_candidate      SPY           1.00
# 1           provisional_core_candidate     CASH           0.00
# 2   provisional_core_inception_limited      SPY           0.50
# 3   provisional_core_inception_limited      QQQ           0.30
# 4   provisional_core_inception_limited      GLD           0.10
# 5   provisional_core_inception_limited      TLT           0.10
# 6    provisional_high_caveat_candidate      SPY           0.50
# 7    provisional_high_caveat_candidate      QQQ           0.45
# 8    provisional_high_caveat_candidate  BTC-USD           0.05
# 9                       reference_only      SPY           0.60
# 10                      reference_only      QQQ           0.40
#
#     target_notional_usd   manual_decision manual_execution_status  \
# 0               10000.0  skip_due_warning                 skipped
# 1                   0.0  skip_due_warning                 skipped
# 2                5000.0  skip_due_warning                 skipped
# 3                3000.0  skip_due_warning                 skipped
# 4                1000.0  skip_due_warning                 skipped
# 5                1000.0  skip_due_warning                 skipped
# 6                5000.0  skip_due_warning                 skipped
# 7                4500.0  skip_due_warning                 skipped
# 8                 500.0  skip_due_warning                 skipped
# 9                6000.0  skip_due_warning                 skipped
# 10               4000.0  skip_due_warning                 skipped
#
#     paper_account_value  ...  actual_notional_usd  deviation_from_preview_usd  \
# 0                   NaN  ...                  NaN                         NaN
# 1                   NaN  ...                  NaN                         NaN
# 2                   NaN  ...                  NaN                         NaN
# 3                   NaN  ...                  NaN                         NaN
# 4                   NaN  ...                  NaN                         NaN
# 5                   NaN  ...                  NaN                         NaN
# 6                   NaN  ...                  NaN                         NaN
# 7                   NaN  ...                  NaN                         NaN
# 8                   NaN  ...                  NaN                         NaN
# 9                   NaN  ...                  NaN                         NaN
# 10                  NaN  ...                  NaN                         NaN
#
#     deviation_from_preview_pct  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
#
#                                     override_reason  \
# 0   first_regime_informed_workflow_validation_cycle
# 1   first_regime_informed_workflow_validation_cycle
# 2   first_regime_informed_workflow_validation_cycle
# 3   first_regime_informed_workflow_validation_cycle
# 4   first_regime_informed_workflow_validation_cycle
# 5   first_regime_informed_workflow_validation_cycle
# 6   first_regime_informed_workflow_validation_cycle
# 7   first_regime_informed_workflow_validation_cycle
# 8   first_regime_informed_workflow_validation_cycle
# 9   first_regime_informed_workflow_validation_cycle
# 10  first_regime_informed_workflow_validation_cycle
#
#                                                 notes  \
# 0   Warnings and candidate caveats acknowledged. S...
# 1   Warnings and candidate caveats acknowledged. S...
# 2   Warnings and candidate caveats acknowledged. S...
# 3   Warnings and candidate caveats acknowledged. S...
# 4   Warnings and candidate caveats acknowledged. S...
# 5   Warnings and candidate caveats acknowledged. S...
# 6   Warnings and candidate caveats acknowledged. S...
# 7   Warnings and candidate caveats acknowledged. S...
# 8   Warnings and candidate caveats acknowledged. S...
# 9   Warnings and candidate caveats acknowledged. S...
# 10  Warnings and candidate caveats acknowledged. S...
#
#                                     candidate_caveats promotion_allowed  \
# 0   original defensive overlay baseline; lower dra...             False
# 1   original defensive overlay baseline; lower dra...             False
# 2   multi-asset regime survivability candidate; as...             False
# 3   multi-asset regime survivability candidate; as...             False
# 4   multi-asset regime survivability candidate; as...             False
# 5   multi-asset regime survivability candidate; as...             False
# 6   BTC high-caveat; inception-limited; weekend/ga...             False
# 7   BTC high-caveat; inception-limited; weekend/ga...             False
# 8   BTC high-caveat; inception-limited; weekend/ga...             False
# 9   reference-only growth benchmark; rejected by r...             False
# 10  reference-only growth benchmark; rejected by r...             False
#
#    live_trading_allowed  real_money_allowed  broker_api_integration_allowed
# 0                 False               False                           False
# 1                 False               False                           False
# 2                 False               False                           False
# 3                 False               False                           False
# 4                 False               False                           False
# 5                 False               False                           False
# 6                 False               False                           False
# 7                 False               False                           False
# 8                 False               False                           False
# 9                 False               False                           False
# 10                False               False                           False
#
# [11 rows x 22 columns]

# %% [markdown]
# ![ledger_decisions](reports/paper_trading/regime_informed_tracking/visuals/ledger_decisions.png)

# %% [markdown]
# ## 11. Daily Runtime Status

# %%
frames['daily_runtime'].head() if not frames['daily_runtime'].empty else 'Daily runtime report missing'
# Out:
#      run_date selected_signal_date  daily_paper_only  \
# 0  2026-06-11           2026-06-08              True
#
#                                          modules_run  \
# 0  phase15q;phase15r;phase15o;phase15p;phase15m;p...
#
#                                      modules_skipped  runtime_seconds  \
# 0  phase17_strategy_factory;phase17b_robustness;p...            0.618
#
#    fresh_signal_available  regime_informed_targets_written  \
# 0                    True                             True
#
#                                      adoption_status  \
# 0  regime_informed_shortlist_adopted_manual_paper...
#
#      session_ingestion_status  ledger_row_count  warnings_present  \
# 0  valid_manual_paper_session                11              True
#
#   blocking_symbols  promotion_allowed  live_trading_allowed  \
# 0             none              False                 False
#
#    real_money_allowed  broker_api_integration_allowed  \
# 0               False                           False
#
#                                  daily_paper_status  \
# 0  daily_paper_workflow_completed_manual_paper_only
#
#                                               notes
# 0  daily_paper_workflow_completed_manual_paper_only

# %% [markdown]
# ![daily_runtime](reports/paper_trading/regime_informed_tracking/visuals/daily_runtime.png)

# %% [markdown]
# ## 12. Next Action Checklist
#
# - Open the latest regime-informed tear sheet.
# - Confirm data warnings and blocks before paper tracking.
# - Confirm BTC caveats when BTC target weight is positive.
# - Use manual paper entries only after review.
# - Keep Phase18/20/21 safety gates in force.
# - Do not use live trading, real money, broker/API, or promotion.
